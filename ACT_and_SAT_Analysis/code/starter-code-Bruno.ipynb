# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# "The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - you are a part of a team that tracks statewide participation and recommends where money is best spent to improve SAT participation rates. Your presentation and report should be geared toward non-technical executives with the College Board and you will use the provided data and outside research to make recommendations about how the College Board might work to increase the participation rate in a state of your choice."
#
# We will look over our data and inspect how a state's participation in a given test impacts their average test scores. Do states that require a particular test score higher on that test? How can we increase participation on the SAT, and where is money best spent to improve SAT participation rates?

# %% [markdown]
# ## Executive Summary
#
# The ACT and SAT are standardized tests used to gauge high school students' understanding of certain subjects, including Math, Reading/Writing, English, and Science. The tests do not test on all of the same subject matters, but their goal is the same: to test each student's understanding of the material and assess their college readiness.
#
# If you're a high school student in the United States, the odds are that at some point you will be expected to take a standardized test prior to your admission to college. Nearly every four-year college or university in the country will require either an ACT or SAT test score to be submitted, with most having a certain minimum threshold that all applicants must meet in order to be considered for admission. In some cases, states may require students to take either the ACT or SAT regardless of whether or not they plan to continue their educational career in college or university.
#
# Throughout this project, we obtained additional necessary data, cleaned our existing data as well as our new data using the `pandas` Python library, consolidated it into one `pandas` DataFrame to make it easier to work with, and applied several `pandas` methods to show tables of different sections of our data. Additionally, we used several plotting libraries within Python, such as `matplotlib` and `seaborn` to plot the data.
#
# **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# !pwd

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %%
# sat_2017 # calls the entire dataframe
# sat_2017.describe() # provides the count, mean, std, min, percentiles, max for each row
# sat_2017.quantile(0.5) # provides quantiles for each numeric column
# sat_2017['Math'] # print just the 'Math' column
# pd.set_option('precision', 2) # sets answers to two decimal places
# sat_2017[sat_2017['State'] == 'District of Columbia'] # filter by state being equal to DC
# sat_2017.columns # see the columns in a list
# sat_2017['Math'].mean() # .mean calls the mean, in this case for the specific column

# %%
# sat_2017[sat_2017['Math'] > 548]

# %%
# act_2017
# act_2017.describe() # provides the count, mean, std, min, percentiles, max for each row

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
# sat_2017 # use this to look through the entire dataset

# %%
# act_2017 # use this to look through the entire dataset

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# For the 2017 SAT data, we have the data broken down by state, with each row representing a different state. The columns show us the participation rate of each state (i.e. the percentage of each state taking the SAT), along with averages for each state in 'Evidence-Based Reading and Writing', 'Math', and the total of the previous two columns combined. We are not immediately presented with National averages.
#
# For the 2017 ACT data, the data is also broken down by state, however in this case the first row of data provides us with the National averages. The columns provide us with the participation rate of each individual state on the ACT (the percentage of each state taking the ACT), along with averages in 'English', 'Math', 'Reading', 'Science', and finally the 'Composite' score. The 'Composite' score is the overall average of all of the categories.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# It looks complete in the sense that there are the right number of states, and there are no null values in any of the rows or columns. We do not know what the maximum obtainable or minimum obtainable values are, just what the maximum or minimum observed values are.
#
# The 2017 SAT scores do not include National averages.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# We do not know what the maximum obtainable or minimum obtainable values are, just what the maximum or minimum observed values are. Some of the values appear to be incorrect, such as the minimum value of the 'Math' column in the SAT dataset, and the minimum value of the 'Science' column in the ACT dataset. Whereas the minimum values for every other test column in the SAT dataset is in three digits, the 'Math' column is two digits. Similarly, whereas the minimum value for every other test category column in the ACT dataset is in two digits, the 'Math' column is in two digits.
#
# This suggests a missing digit in both cases. Upon closer inspection, the 'Maryland' row has an incorrect value for 'Math' in the 2017 SAT data, and an incorrect value for 'Science' in the 2017 ACT data. Furthermore, 'Wyoming' has an 'x' at the end of the 'Composite' value.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
sat_2017.loc[20, 'Math'] = 524
# sat_2017.Math.replace(52, 524, inplace = True)
# sat_2017

act_2017.loc[21, 'Science'] = 23.2
act_2017.loc[51, 'Composite'] = 20.2
# act_2017.Science.replace(2.3, 23.2, inplace = True)
# act_2017.Composite.replace('20.2x', 20.2, inplace = True)
# act_2017

# code below adds 'National' to SAT

# sat_2017.loc[-1] = ['National', np.nan, 533, 527, 1060]
# sat_2017.index = sat_2017.index + 1
# sat_2017 = sat_2017.sort_index()

# code to add 'National' adapted from:
# https://stackoverflow.com/questions/24284342/insert-a-row-to-pandas-dataframe

# %%
# sat_2017

# %%
# act_2017

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# The 'Composite' column is of type object, when it should be float64. This is likely due to the 'typo' where Wyoming's 'Composite' score was '20.2x'.
#
# Participation will likely be easier to work with as a float64 or int64, but that will require us to remove the '%' symbol and, in the case of float64 and having the participation between 0 and 1, divide by 100.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# sat_2017['Participation'] = sat_2017['Participation'].str.strip('%')
# act_2017['Participation'] = act_2017['Participation'].str.strip('%')

def remove_pct(value):
    return value.strip('%')
    
sat_2017['Participation'] = sat_2017['Participation'].apply(remove_pct)
act_2017['Participation'] = act_2017['Participation'].apply(remove_pct)

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama             5                                 593   572   1165
# 1      Alaska            38                                 547   533   1080
# 2     Arizona            30                                 563   553   1116
# 3    Arkansas             3                                 614   594   1208
# 4  California            53                                 531   524   1055

# %%
#code

# this doesn't work

# def participation_to_float(x):
#     x = x.strip('%')
#     try:
#         out = int(x)
#     except:
#         pass

# %%
# sat_2017

# %%
# act_2017

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017['Composite'] = act_2017['Composite'].astype(float)
act_2017['Participation'] = act_2017['Participation'].astype(int)
sat_2017['Participation'] = sat_2017['Participation'].astype(int)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
sat_2017.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017.rename(columns = {
    'State': 'state',
    'Participation': 'sat_participation',
    'Evidence-Based Reading and Writing': 'sat_eb_reading_and_writing',
    'Math': 'sat_math',
    'Total': 'sat_total'}, inplace = True)

act_2017.rename(columns = {
    'State': 'state',
    'Participation': 'act_participation',
    'English': 'act_english',
    'Math': 'act_math',
    'Reading': 'act_reading',
    'Science': 'act_science',
    'Composite': 'act_composite'}, inplace = True)

# %%
sat_2017.head(1)
# Out:
#      state  sat_participation  sat_eb_reading_and_writing  sat_math  sat_total
# 0  Alabama                  5                         593       572       1165

# %%
act_2017.head(1)
# Out:
#       state  act_participation  act_english  act_math  act_reading  \
# 0  National                 60         20.3      20.7         21.4
#
#    act_science  act_composite
# 0         21.0           21.0

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT/ACT|The state our row refers to|
# |sat_participation|integer|SAT|The percentage of students in the given state that took the SAT in 2017|
# |sat_participation_2018|integer|SAT|The percentage of students in the given state that took the SAT in 2018|
# |act_participation|integer|ACT|The percentage of students in the given state that took the SAT in 2017|
# |act_participation_2018|integer|ACT|The percentage of students in the given state that took the SAT in 2018|
# |sat_eb_reading_and_writing|integer|SAT|The average score per state on the 'Evidence-Based Reading and Writing' portion of the SAT exam in 2017|
# |sat_eb_reading_and_writing_2018|integer|SAT|The average score per state on the 'Evidence-Based Reading and Writing' portion of the SAT exam|
# |sat_math|integer|SAT|The average score per state on the 'Math' portion of the SAT exam in 2017|
# |sat_math_2018|integer|SAT|The average score per state on the 'Math' portion of the SAT exam in 2018|
# |sat_total|integer|SAT|The total combined average score per state of the 'Evidence-Based Reading and Writing' and 'Math' portions of the SAT exam in 2017|
# |sat_total_2018|integer|SAT|The total combined average score per state of the 'Evidence-Based Reading and Writing' and 'Math' portions of the SAT exam in 2018|
# |act_english|float|ACT|The average score per state on the 'English' portion of the ACT exam in 2017|
# |act_english_2018|float|ACT|The average score per state on the 'English' portion of the ACT exam in 2018|
# |act_math|float|ACT|The average score per state on the 'Math' portion of the ACT exam in 2017|
# |act_math_2018|float|ACT|The average score per state on the 'Math' portion of the ACT exam in 2018|
# |act_reading|float|ACT|The average score per state on the 'Reading' portion of the ACT exam in 2017|
# |act_reading_2018|float|ACT|The average score per state on the 'Reading' portion of the ACT exam in 2018|
# |act_science|float|ACT|The average score per state on the 'Science' portion of the ACT exam in 2017|
# |act_science_2018|float|ACT|The average score per state on the 'Science' portion of the ACT exam in 2018|
# |act_composite|float|ACT|The average score per state of the combined 'English', 'Math', 'Reading', and 'Science' portions of the ACT exam in 2017|
# |act_composite|float|ACT|The average score per state of the combined 'English', 'Math', 'Reading', and 'Science' portions of the ACT exam in 2018|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code

act_2017.drop(0, axis = 0, inplace = True)

# %%
# call act_2017 to check and make sure the 0th row ('National') was dropped
# act_2017

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
sat_act_2017 = pd.merge(sat_2017, act_2017, on = 'state')

# https://stackoverflow.com/questions/18792918/combine-two-pandas-data-frames-join-on-a-common-column

# %%
# sat_act_2017

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
sat_act_2017.to_csv('../data/combined_2017.csv')

# %%
# sat_act_2017

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Import the data sets and save them with appropriate variable names
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
# Rename the columns so they're clear, but also different from the 2017 columns
sat_2018.rename(columns = {
    'State': 'state',
    'Participation': 'sat_participation_2018',
    'Evidence-Based Reading and Writing': 'sat_eb_reading_and_writing_2018',
    'Math': 'sat_math_2018',
    'Total': 'sat_total_2018'}, inplace = True)

act_2018.rename(columns = {
    'State': 'state',
    'Percentage of Students Tested': 'act_participation_2018',
    'Average English Score': 'act_english_2018',
    'Average Math Score': 'act_math_2018',
    'Average Reading Score': 'act_reading_2018',
    'Average Science Score': 'act_science_2018',
    'Average Composite Score': 'act_composite_2018'}, inplace = True)

# %%
# remove the '%' from the SAT participation column
sat_2018['sat_participation_2018'] = sat_2018['sat_participation_2018'].str.strip('%')

# %%
# set the datatype of sat_participation_2018 equal to int
sat_2018['sat_participation_2018'] = sat_2018['sat_participation_2018'].astype(int)

# %%
# sat_2018.dtypes
# act_2018.dtypes

# %%
# act_2018

# %%
sat_act_2018 = pd.merge(sat_2018, act_2018, on = 'state')

# %%
#code
sat_act_2018.to_csv('../data/combined_2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.merge(sat_act_2017, sat_act_2018, on = 'state')

# %%
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe()
# Out:
#        sat_participation  sat_eb_reading_and_writing    sat_math    sat_total  \
# count          51.000000                   51.000000   51.000000    51.000000
# mean           39.803922                  569.117647  556.882353  1126.098039
# std            35.276632                   45.666901   47.121395    92.494812
# min             2.000000                  482.000000  468.000000   950.000000
# 25%             4.000000                  533.500000  523.500000  1055.500000
# 50%            38.000000                  559.000000  548.000000  1107.000000
# 75%            66.000000                  613.000000  599.000000  1212.000000
# max           100.000000                  644.000000  651.000000  1295.000000
#
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean           65.254902    20.931373  21.182353    22.013725    21.450980
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code

# finds the mean by taking the sum of the data divided by how many data points
def mean(data):
    return float(sum(data) / len(data))

# find the variance by setting the mean equal to mu, subtracting mu from each x value in the column
# squaring all of those differences, and returning the mean of that list
def variance(data):
    mu = mean(data)
    return mean([(x - mu) ** 2 for x in data])

#square root of the variance
def std_dev(data):
    return (variance(data)) ** 0.5

# code taken from Stack Overflow [https://stackoverflow.com/questions/36830737/writing-a-standard-deviation-function]

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.columns[1:]
# Out:
# Index(['sat_participation', 'sat_eb_reading_and_writing', 'sat_math',
#        'sat_total', 'act_participation', 'act_english', 'act_math',
#        'act_reading', 'act_science', 'act_composite', 'sat_participation_2018',
#        'sat_eb_reading_and_writing_2018', 'sat_math_2018', 'sat_total_2018',
#        'act_participation_2018', 'act_composite_2018', 'act_english_2018',
#        'act_math_2018', 'act_reading_2018', 'act_science_2018'],
#       dtype='object')

# %%
sd = {i: std_dev(final[i]) for i in final.columns[1:]}

# help with code from Andrew Picart, inspiration from Josh Robin blog

# %%
# THIS ISN'T DICTIONARY COMPREHENSION

# #Code:
# sd = {'sat_participation': std_dev(final['sat_participation']),
#       'sat_eb_reading_and_writing': std_dev(final['sat_eb_reading_and_writing']),
#       'sat_math': std_dev(final['sat_math']),
#       'sat_total': std_dev(final['sat_total']),
#       'act_participation': std_dev(final['act_participation']),
#       'act_english': std_dev(final['act_english']),
#       'act_math': std_dev(final['act_math']),
#       'act_reading': std_dev(final['act_reading']),
#       'act_science': std_dev(final['act_science']),
#       'act_composite': std_dev(final['act_composite']),
#       'sat_participation_2018': std_dev(final['sat_participation_2018']),
#       'sat_eb_reading_and_writing_2018': std_dev(final['sat_eb_reading_and_writing_2018']),
#       'sat_math_2018': std_dev(final['sat_math_2018']),
#       'sat_total_2018': std_dev(final['sat_total_2018']),
#       'act_participation_2018': std_dev(final['act_participation_2018']),
#       'act_composite_2018': std_dev(final['act_composite_2018']),
#       'act_english_2018': std_dev(final['act_english_2018']),
#       'act_math_2018': std_dev(final['act_math_2018']),
#       'act_reading_2018': std_dev(final['act_reading_2018']),
#       'act_science_2018': std_dev(final['act_science_2018'])}

# %%
sd
# Out:
# {'sat_participation': 34.92907076664508,
#  'sat_eb_reading_and_writing': 45.21697020437866,
#  'sat_math': 46.65713364485503,
#  'sat_total': 91.58351056778743,
#  'act_participation': 31.824175751231806,
#  'act_english': 2.3304876369363363,
#  'act_math': 1.9624620273436781,
#  'act_reading': 2.0469029314842646,
#  'act_science': 1.7222161451443676,
#  'act_composite': 2.000786081581989,
#  'sat_participation_2018': 36.946619223539415,
#  'sat_eb_reading_and_writing_2018': 47.03460978357609,
#  'sat_math_2018': 47.30194550378352,
#  'sat_total_2018': 93.22742384464433,
#  'act_participation_2018': 33.745194881997506,
#  'act_composite_2018': 2.0855261815801147,
#  'act_english_2018': 2.4222536143202795,
#  'act_math_2018': 2.015707255555717,
#  'act_reading_2018': 2.145891884510421,
#  'act_science_2018': 1.8516885484833543}

# %%
numpy_std = {i: np.std(final[i]) for i in final.columns[1:]}

# %%
numpy_std
# Out:
# {'sat_participation': 34.92907076664508,
#  'sat_eb_reading_and_writing': 45.21697020437866,
#  'sat_math': 46.65713364485503,
#  'sat_total': 91.58351056778743,
#  'act_participation': 31.824175751231806,
#  'act_english': 2.3304876369363363,
#  'act_math': 1.9624620273436781,
#  'act_reading': 2.0469029314842646,
#  'act_science': 1.7222161451443676,
#  'act_composite': 2.000786081581989,
#  'sat_participation_2018': 36.946619223539415,
#  'sat_eb_reading_and_writing_2018': 47.03460978357609,
#  'sat_math_2018': 47.30194550378352,
#  'sat_total_2018': 93.22742384464433,
#  'act_participation_2018': 33.745194881997506,
#  'act_composite_2018': 2.0855261815801147,
#  'act_english_2018': 2.4222536143202795,
#  'act_math_2018': 2.015707255555717,
#  'act_reading_2018': 2.145891884510421,
#  'act_science_2018': 1.8516885484833543}

# %%
final.describe()
# Out:
#        sat_participation  sat_eb_reading_and_writing    sat_math    sat_total  \
# count          51.000000                   51.000000   51.000000    51.000000
# mean           39.803922                  569.117647  556.882353  1126.098039
# std            35.276632                   45.666901   47.121395    92.494812
# min             2.000000                  482.000000  468.000000   950.000000
# 25%             4.000000                  533.500000  523.500000  1055.500000
# 50%            38.000000                  559.000000  548.000000  1107.000000
# 75%            66.000000                  613.000000  599.000000  1212.000000
# max           100.000000                  644.000000  651.000000  1295.000000
#
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean           65.254902    20.931373  21.182353    22.013725    21.450980
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# The manually calculated standard deviations match with numpy's `std` method, but not with the pandas `describe` function

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# lowest participation rates in 2017 SAT
final.sort_values('sat_participation').head()

# North Dakota, Mississippi, Iowa all had 2% participation on the SAT in 2017
# Out:
#            state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 34  North Dakota                  2                         635       621
# 24   Mississippi                  2                         634       607
# 15          Iowa                  2                         641       635
# 25      Missouri                  3                         640       631
# 44          Utah                  3                         624       614
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 34       1256                 98         19.0      20.4         20.5
# 24       1242                100         18.2      18.1         18.8
# 15       1275                 67         21.2      21.3         22.6
# 25       1271                100         19.8      19.9         20.8
# 44       1238                100         19.5      19.9         20.8
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# highest participation rates in 2017 SAT
final.sort_values('sat_participation', ascending = False).head()

# DC, Michigan, Connecticut, Delaware all had 100% participation on the SAT in 2017
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 8   District of Columbia                100                         482
# 22              Michigan                100                         509
# 6            Connecticut                100                         530
# 7               Delaware                100                         503
# 29         New Hampshire                 96                         532
#
#     sat_math  sat_total  act_participation  act_english  act_math  \
# 8        468        950                 32         24.4      23.5
# 22       495       1005                 29         24.1      23.7
# 6        512       1041                 31         25.5      24.6
# 7        492        996                 18         24.1      23.4
# 29       520       1052                 18         25.4      25.1
#
#     act_reading  act_science  ...  sat_participation_2018  \
# 8          24.9         23.5  ...                      92
# ...

# %%
# lowest participation rates in 2018 SAT
final.sort_values('sat_participation_2018').head().T

# North Dakota continued from 2017 with a 2% participation rate on the 2018 SAT
# 6 states had 3% participation rates
## Wyoming, South Dakota, Nebraska, Wisconsin, Mississippi, Iowa
# Out:
#                                            34       50            41  \
# state                            North Dakota  Wyoming  South Dakota
# sat_participation                           2        3             3
# sat_eb_reading_and_writing                635      626           612
# sat_math                                  621      604           603
# sat_total                                1256     1230          1216
# act_participation                          98      100            80
# act_english                                19     19.4          20.7
# act_math                                 20.4     19.8          21.5
# act_reading                              20.5     20.8          22.3
# act_science                              20.6     20.6            22
# act_composite                            20.3     20.2          21.8
# sat_participation_2018                      2        3             3
# sat_eb_reading_and_writing_2018           640      633           622
# ...

# %%
# highest participation rates in 2018 SAT
final.sort_values('sat_participation_2018', ascending = False).head().T

# Colorado, Connecticut, Delaware, Michigan, Idaho all had 100% participation on the 2018 SAT
# Out:
#                                        5            6         7         22  \
# state                            Colorado  Connecticut  Delaware  Michigan
# sat_participation                      11          100       100       100
# sat_eb_reading_and_writing            606          530       503       509
# sat_math                              595          512       492       495
# sat_total                            1201         1041       996      1005
# act_participation                     100           31        18        29
# act_english                          20.1         25.5      24.1      24.1
# act_math                             20.3         24.6      23.4      23.7
# act_reading                          21.2         25.6      24.8      24.5
# act_science                          20.9         24.6      23.6      23.8
# act_composite                        20.8         25.2      24.1      24.1
# ...

# %%
# lowest participation rates in 2017 ACT
final.sort_values('act_participation').head()

# Maine (8%), New Hampshire (18%), and Delaware (18%) had participation rates below 20% on the 2017 ACT
# Out:
#             state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 19          Maine                 95                         513       499
# 29  New Hampshire                 96                         532       520
# 7        Delaware                100                         503       492
# 39   Rhode Island                 71                         539       524
# 38   Pennsylvania                 65                         540       531
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 19       1012                  8         24.2      24.0         24.8
# 29       1052                 18         25.4      25.1         26.0
# 7         996                 18         24.1      23.4         24.8
# 39       1062                 21         24.0      23.3         24.7
# 38       1071                 23         23.4      23.4         24.2
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# highest participation rates in 2017 ACT
final.sort_values('act_participation', ascending = False).head()

# 17 states had a 100% participation rate on the 2017 ACT
# Out:
#         state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 0     Alabama                  5                         593       572
# 17   Kentucky                  4                         631       616
# 49  Wisconsin                  3                         642       649
# 44       Utah                  3                         624       614
# 42  Tennessee                  5                         623       604
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 0        1165                100         18.9      18.4         19.7
# 17       1247                100         19.6      19.4         20.5
# 49       1291                100         19.7      20.4         20.6
# 44       1238                100         19.5      19.9         20.8
# 42       1228                100         19.5      19.2         20.1
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# lowest participation rates in 2018 ACT
final.sort_values('act_participation_2018').head().T

# Maine (7%), Rhode Island (15%), New Hampshire (16%), Delaware (17%) had participation rates below 20%
# in the 2018 ACT
# Out:
#                                     19            39             29        7   \
# state                            Maine  Rhode Island  New Hampshire  Delaware
# sat_participation                   95            71             96       100
# sat_eb_reading_and_writing         513           539            532       503
# sat_math                           499           524            520       492
# sat_total                         1012          1062           1052       996
# act_participation                    8            21             18        18
# act_english                       24.2            24           25.4      24.1
# act_math                            24          23.3           25.1      23.4
# act_reading                       24.8          24.7             26      24.8
# act_science                       23.7          23.4           24.9      23.6
# act_composite                     24.3            24           25.5      24.1
# ...

# %%
# highest participation rates in 2018 ACT
final.sort_values('act_participation_2018', ascending = False).head().T

# 17 states had 100% participation in the 2018 ACT
# Out:
#                                       0         17         49    44         42
# state                            Alabama  Kentucky  Wisconsin  Utah  Tennessee
# sat_participation                      5         4          3     3          5
# sat_eb_reading_and_writing           593       631        642   624        623
# sat_math                             572       616        649   614        604
# sat_total                           1165      1247       1291  1238       1228
# act_participation                    100       100        100   100        100
# act_english                         18.9      19.6       19.7  19.5       19.5
# act_math                            18.4      19.4       20.4  19.9       19.2
# act_reading                         19.7      20.5       20.6  20.8       20.1
# act_science                         19.4      20.1       20.9  20.6       19.9
# act_composite                       19.2        20       20.5  20.3       19.8
# ...

# %%
# lowest total SAT score, 2017
final.sort_values('sat_total').head()

# DC and Delaware had the lowest total 2017 SAT scores, both below 1000
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 8   District of Columbia                100                         482
# 7               Delaware                100                         503
# 12                 Idaho                 93                         513
# 22              Michigan                100                         509
# 19                 Maine                 95                         513
#
#     sat_math  sat_total  act_participation  act_english  act_math  \
# 8        468        950                 32         24.4      23.5
# 7        492        996                 18         24.1      23.4
# 12       493       1005                 38         21.9      21.8
# 22       495       1005                 29         24.1      23.7
# 19       499       1012                  8         24.2      24.0
#
#     act_reading  act_science  ...  sat_participation_2018  \
# 8          24.9         23.5  ...                      92
# ...

# %%
# highest total SAT score, 2017
final.sort_values('sat_total', ascending = False).head()

# Minnesota, Wisconsin, and Iowa were the top 3 states in total 2017 SAT score
# Out:
#         state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 23  Minnesota                  3                         644       651
# 49  Wisconsin                  3                         642       649
# 15       Iowa                  2                         641       635
# 25   Missouri                  3                         640       631
# 16     Kansas                  4                         632       628
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 23       1295                100         20.4      21.5         21.8
# 49       1291                100         19.7      20.4         20.6
# 15       1275                 67         21.2      21.3         22.6
# 25       1271                100         19.8      19.9         20.8
# 16       1260                 73         21.1      21.3         22.3
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# lowest total SAT score, 2018
final.sort_values('sat_total_2018').head()

# DC (977), Delaware (998), and West Virginia (999) had 2018 total SAT scores below 1000
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 8   District of Columbia                100                         482
# 7               Delaware                100                         503
# 48         West Virginia                 14                         558
# 12                 Idaho                 93                         513
# 44                  Utah                  3                         624
#
#     sat_math  sat_total  act_participation  act_english  act_math  \
# 8        468        950                 32         24.4      23.5
# 7        492        996                 18         24.1      23.4
# 48       528       1086                 69         20.0      19.4
# 12       493       1005                 38         21.9      21.8
# 44       614       1238                100         19.5      19.9
#
#     act_reading  act_science  ...  sat_participation_2018  \
# 8          24.9         23.5  ...                      92
# ...

# %%
# highest total SAT score, 2018
final.sort_values('sat_total_2018', ascending = False).head()

# Minnesota(1298), Wisconsin (1294), and North Dakota (1283) had the highest 2018 total SAT scores
# Out:
#            state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 23     Minnesota                  3                         644       651
# 49     Wisconsin                  3                         642       649
# 34  North Dakota                  2                         635       621
# 15          Iowa                  2                         641       635
# 16        Kansas                  4                         632       628
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 23       1295                100         20.4      21.5         21.8
# 49       1291                100         19.7      20.4         20.6
# 34       1256                 98         19.0      20.4         20.5
# 15       1275                 67         21.2      21.3         22.6
# 16       1260                 73         21.1      21.3         22.3
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# lowest composite ACT score, 2017
final.sort_values('act_composite').head().T

# Nevada (17.8), Mississippi (18.6), and South Carolina (18.7) had 2017 composite ACT scores below 19
# Out:
#                                      28           24              40      11  \
# state                            Nevada  Mississippi  South Carolina  Hawaii
# sat_participation                    26            2              50      55
# sat_eb_reading_and_writing          563          634             543     544
# sat_math                            553          607             521     541
# sat_total                          1116         1242            1064    1085
# act_participation                   100          100             100      90
# act_english                        16.3         18.2            17.5    17.8
# act_math                             18         18.1            18.6    19.2
# act_reading                        18.1         18.8            19.1    19.2
# act_science                        18.2         18.8            18.9    19.3
# act_composite                      17.8         18.6            18.7      19
# ...

# %%
# highest composite ACT score, 2017
final.sort_values('act_composite', ascending = False).head().T

# New Hampshire (25.5), Massachusetts (25.4), and Connecticut (25.2) had 2017 composite ACT scores above 25
# Out:
#                                             29             21           6   \
# state                            New Hampshire  Massachusetts  Connecticut
# sat_participation                           96             76          100
# sat_eb_reading_and_writing                 532            555          530
# sat_math                                   520            551          512
# sat_total                                 1052           1107         1041
# act_participation                           18             29           31
# act_english                               25.4           25.4         25.5
# act_math                                  25.1           25.3         24.6
# act_reading                                 26           25.9         25.6
# act_science                               24.9           24.7         24.6
# act_composite                             25.5           25.4         25.2
# ...

# %%
# lowest composite ACT score, 2018
final.sort_values('act_composite_2018').head()

# Nevada (17.7) had the only composite 2018 ACT score below 18
# South Carolina (18.3), Mississippi (18.6), and Hawaii (18.9) were the only other 3 states below 19
# Out:
#              state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 28          Nevada                 26                         563       553
# 40  South Carolina                 50                         543       521
# 24     Mississippi                  2                         634       607
# 11          Hawaii                 55                         544       541
# 0          Alabama                  5                         593       572
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 28       1116                100         16.3      18.0         18.1
# 40       1064                100         17.5      18.6         19.1
# 24       1242                100         18.2      18.1         18.8
# 11       1085                 90         17.8      19.2         19.2
# 0        1165                100         18.9      18.4         19.7
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
# highest composite ACT score, 2018
final.sort_values('act_composite_2018', ascending = False).head()

# Connecticut (25.6), Massachusetts (25.5), and New Hampshire (25.1) were the only 3 states with composite 2018 ACT 
# scores above 25
# Out:
#             state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 6     Connecticut                100                         530       512
# 21  Massachusetts                 76                         555       551
# 29  New Hampshire                 96                         532       520
# 32       New York                 67                         528       523
# 22       Michigan                100                         509       495
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 6        1041                 31         25.5      24.6         25.6
# 21       1107                 29         25.4      25.3         25.9
# 29       1052                 18         25.4      25.1         26.0
# 32       1052                 31         23.8      24.0         24.6
# 22       1005                 29         24.1      23.7         24.5
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
final[(final['sat_participation'] < 50) & (final['act_participation'] < 50)].head()

# Oregon had less than 50% participation on both the SAT and ACT in 2017
# Out:
#      state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 37  Oregon                 43                         560       548
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 37       1108                 40         21.2      21.5         22.4
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# 37         21.7  ...                      48                              564
#
#     sat_math_2018  sat_total_2018  act_participation_2018  act_composite_2018  \
# 37            553            1117                      42                21.3
#
#     act_english_2018  act_math_2018  act_reading_2018  act_science_2018
# 37              20.6           20.9              21.9              21.1
#
# [1 rows x 21 columns]

# %%
final[(final['sat_participation_2018'] < 50) & (final['act_participation_2018'] < 50)].head()

# Oregon and Alaska had less than 50% participation on both the SAT and ACT in 2018
# Out:
#      state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 1   Alaska                 38                         547       533
# 37  Oregon                 43                         560       548
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 1        1080                 65         18.7      19.8         20.4
# 37       1108                 40         21.2      21.5         22.4
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# 1          19.9  ...                      43                              562
# 37         21.7  ...                      48                              564
#
#     sat_math_2018  sat_total_2018  act_participation_2018  act_composite_2018  \
# 1             544            1106                      33                20.8
# 37            553            1117                      42                21.3
#
#     act_english_2018  act_math_2018  act_reading_2018  act_science_2018
# ...

# %%
final[(final['act_participation'] > 50) & (final['act_participation_2018'] > 50)].head()

# Alabama, Arizona, Arkansas, Florida, and Georgia had greater than 50% participation in the ACT
# for both 2017 and 2018
# Out:
#        state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 0    Alabama                  5                         593       572
# 2    Arizona                 30                         563       553
# 3   Arkansas                  3                         614       594
# 9    Florida                 83                         520       497
# 10   Georgia                 61                         535       515
#
#     sat_total  act_participation  act_english  act_math  act_reading  \
# 0        1165                100         18.9      18.4         19.7
# 2        1116                 62         18.6      19.8         20.1
# 3        1208                100         18.9      19.0         19.7
# 9        1017                 73         19.0      19.4         21.0
# 10       1050                 55         21.0      20.9         22.0
#
#     act_science  ...  sat_participation_2018  sat_eb_reading_and_writing_2018  \
# ...

# %%
final[(final['sat_participation'] > 50) & (final['sat_participation_2018'] > 50)].head()

# California, Connecticut, Delaware, DC, and Florida had greater than 50% participation rates
# on the SATs for both 2017 and 2018.
# Out:
#                   state  sat_participation  sat_eb_reading_and_writing  \
# 4            California                 53                         531
# 6           Connecticut                100                         530
# 7              Delaware                100                         503
# 8  District of Columbia                100                         482
# 9               Florida                 83                         520
#
#    sat_math  sat_total  act_participation  act_english  act_math  act_reading  \
# 4       524       1055                 31         22.5      22.7         23.1
# 6       512       1041                 31         25.5      24.6         25.6
# 7       492        996                 18         24.1      23.4         24.8
# 8       468        950                 32         24.4      23.5         24.9
# 9       497       1017                 73         19.0      19.4         21.0
#
# ...

# %%
final[(final['sat_participation'] == 100) | (final['sat_participation_2018'] == 100)]
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 5               Colorado                 11                         606
# 6            Connecticut                100                         530
# 7               Delaware                100                         503
# 8   District of Columbia                100                         482
# 12                 Idaho                 93                         513
# 22              Michigan                100                         509
#
#     sat_math  sat_total  act_participation  act_english  act_math  \
# 5        595       1201                100         20.1      20.3
# 6        512       1041                 31         25.5      24.6
# 7        492        996                 18         24.1      23.4
# 8        468        950                 32         24.4      23.5
# 12       493       1005                 38         21.9      21.8
# ...

# %%
final[(final['act_participation'] == 100) | (final['act_participation_2018'] == 100)]

# Colorado had 100% participation on the ACT in 2017 and dropped to 30% in 2018
# Colorado also jumped from 11% SAT participation in 2017 to 100% participation in 2018
# Minnesota had a very insignificant drop from 100% to 99%
# Out:
#              state  sat_participation  sat_eb_reading_and_writing  sat_math  \
# 0          Alabama                  5                         593       572
# 3         Arkansas                  3                         614       594
# 5         Colorado                 11                         606       595
# 17        Kentucky                  4                         631       616
# 18       Louisiana                  4                         611       586
# 23       Minnesota                  3                         644       651
# 24     Mississippi                  2                         634       607
# 25        Missouri                  3                         640       631
# 26         Montana                 10                         605       591
# 27        Nebraska                  3                         629       625
# 28          Nevada                 26                         563       553
# ...

# %%
participation_rates = final[['state', 'sat_participation', 'sat_participation_2018',
                             'act_participation', 'act_participation_2018']]

# %%
participation_rates[(participation_rates['sat_participation'] == 100) | (participation_rates['sat_participation_2018'] == 100)]
# Out:
#                    state  sat_participation  sat_participation_2018  \
# 5               Colorado                 11                     100
# 6            Connecticut                100                     100
# 7               Delaware                100                     100
# 8   District of Columbia                100                      92
# 12                 Idaho                 93                     100
# 22              Michigan                100                     100
#
#     act_participation  act_participation_2018
# 5                 100                      30
# 6                  31                      26
# 7                  18                      17
# 8                  32                      32
# 12                 38                      36
# 22                 29                      22

# %%
participation_rates[(participation_rates['act_participation'] == 100) | (participation_rates['act_participation_2018'] == 100)]
# Out:
#              state  sat_participation  sat_participation_2018  \
# 0          Alabama                  5                       6
# 3         Arkansas                  3                       5
# 5         Colorado                 11                     100
# 17        Kentucky                  4                       4
# 18       Louisiana                  4                       4
# 23       Minnesota                  3                       4
# 24     Mississippi                  2                       3
# 25        Missouri                  3                       4
# 26         Montana                 10                      10
# 27        Nebraska                  3                       3
# 28          Nevada                 26                      23
# 33  North Carolina                 49                      52
# 35            Ohio                 12                      18
# 36        Oklahoma                  7                       8
# ...

# %%
final.sort_values('sat_participation')
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 34          North Dakota                  2                         635
# 24           Mississippi                  2                         634
# 15                  Iowa                  2                         641
# 25              Missouri                  3                         640
# 44                  Utah                  3                         624
# 41          South Dakota                  3                         612
# 27              Nebraska                  3                         629
# 49             Wisconsin                  3                         642
# 23             Minnesota                  3                         644
# 50               Wyoming                  3                         626
# 3               Arkansas                  3                         614
# 16                Kansas                  4                         632
# ...

# %%
final.sort_values('sat_participation', ascending = False)
# Out:
#                    state  sat_participation  sat_eb_reading_and_writing  \
# 8   District of Columbia                100                         482
# 22              Michigan                100                         509
# 6            Connecticut                100                         530
# 7               Delaware                100                         503
# 29         New Hampshire                 96                         532
# 19                 Maine                 95                         513
# 12                 Idaho                 93                         513
# 9                Florida                 83                         520
# 21         Massachusetts                 76                         555
# 39          Rhode Island                 71                         539
# 30            New Jersey                 70                         530
# 20              Maryland                 69                         536
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (15, 9))
plt.title('Correlation Between 2017 and 2018 SAT and ACT Participation Rates and Scores', fontsize = 20)
mask = np.zeros_like(final.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(final.corr(), cmap = 'coolwarm', annot = True, mask = mask)

# %%
plt.figure(figsize = (15, 9))
plt.title('Correlation Between 2017 and 2018 SAT and ACT Participation Rates', fontsize = 20)
mask = np.zeros_like(participation_rates.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(participation_rates.corr(), cmap = 'coolwarm', annot = True, mask = mask)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (12, 9)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i], fontsize = 20)
        ax[i].set_ylabel('Number of States',fontsize=15)
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=15);
#         ax[i].set_ylim(top = top_lim)
#         ax[i].set_yticks([0, 5, 10, 15, 20])
    plt.tight_layout()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
sns.set_style()
subplot_histograms(final,
                   ['sat_participation', 'sat_participation_2018',
                    'act_participation', 'act_participation_2018'],
                   ['2017 SAT Participation by\n Number of States', '2018 SAT Participation by\n Number of States',
                    '2017 ACT Participation by\n Number of States', '2018 ACT Participation by\n Number of States'],
                   ['Participation Rate', 'Participation Rate',
                    'Participation Rate', 'Participation Rate'])

# %%
# # Code
# subplot_histograms(final,
#                    ['act_participation', 'act_participation_2018'],
#                    ['2017 ACT Participation by\n Number of States', '2018 ACT Participation by\n Number of States'],
#                    ['Participation Rate', 'Participation Rate'])

# %%
subplot_histograms(final,
                   ['sat_math', 'sat_math_2018',
                    'act_math', 'act_math_2018'],
                   ['2017 Average SAT Math Score\n by Number of States', 
                    '2018 Average SAT Math Score\n by Number of States',
                    '2017 Average ACT Math Score\n by Number of States', 
                    '2018 Average ACT Math Score\n by Number of States'],
                   ['Math Score', 'Math Score',
                    'Math Score', 'Math Score'])

# %%
subplot_histograms(final,
                   ['sat_eb_reading_and_writing', 'sat_eb_reading_and_writing_2018',
                    'act_reading', 'act_reading_2018'],
                   ['2017 Average SAT R&W Score\n by Number of States', 
                    '2018 Average SAT R&W Score\n by Number of States',
                    '2017 Average ACT Reading Score\n by Number of States', 
                    '2018 Average ACT Reading Score\n by Number of States'],
                   ['R&W Score', 'R&W Score',
                    'Reading Score', 'Reading Score'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# SAT vs. ACT math scores for 2017

plt.figure(figsize = (8, 6))
plt.title('2017 SAT Math vs. 2017 ACT Math Scores', fontsize = 20)
plt.xlabel('2017 ACT Math Scores', fontsize = 15)
plt.ylabel('2018 SAT Math Scores', fontsize = 15)
plt.tight_layout()
plt.scatter(final['sat_math'], final['act_math']);

# %%
# SAT vs. ACT verbal/reading scores for 2017

plt.figure(figsize = (8, 6))
plt.title('2017 SAT R&W vs. 2017 ACT Reading Scores', fontsize = 20)
plt.xlabel('2017 ACT Reading Scores', fontsize = 15)
plt.ylabel('2017 SAT R&W Scores', fontsize = 15)
plt.tight_layout()
plt.scatter(final['sat_eb_reading_and_writing'], final['act_reading']);

# %%
# SAT vs. ACT total/composite scores for 2017

plt.figure(figsize = (8, 6))
plt.title('2017 SAT Total vs. 2017 ACT Composite Scores', fontsize = 20)
plt.xlabel('2017 ACT Composite Scores', fontsize = 15)
plt.ylabel('2017 SAT Total Scores', fontsize = 15)
plt.tight_layout()
plt.scatter(final['sat_total'], final['act_composite']);

# %%
# Total scores for SAT 2017 vs. 2018

plt.figure(figsize = (8, 6))
plt.title('2017 SAT Total vs. 2018 SAT Total Scores', fontsize = 20)
plt.xlabel('2017 SAT Total Scores', fontsize = 15)
plt.ylabel('2018 SAT Total Scores', fontsize = 15)
plt.tight_layout()
plt.scatter(final['sat_total'], final['sat_total_2018']);

# %%
# Composite scores for ACT 2017 vs. 2018

plt.figure(figsize = (8, 6))
plt.title('2017 ACT Composite vs. 2018 ACT Composite Scores', fontsize = 20)
plt.xlabel('2017 ACT Composite Scores', fontsize = 15)
plt.ylabel('2018 ACT Composite Scores', fontsize = 15)
plt.tight_layout()
plt.scatter(final['act_composite'], final['act_composite_2018']);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code

plt.figure(figsize = (8, 6))
plt.title('2017 and 2018 Total SAT Scores', fontsize = 20)
sns.boxplot(data = (final['sat_total'], final['sat_total_2018']), 
            orient = 'h', width = 0.5).set_yticklabels(['2017 SAT Total Score', '2018 SAT Total Score']);

# %%
plt.figure(figsize = (8, 6))
plt.title('2017 and 2018 Composite ACT Scores', fontsize = 20)
sns.boxplot(data = [final['act_composite'], final['act_composite_2018']],
            orient = 'h', width = 0.5).set_yticklabels(['2017 Composite ACT Score', '2018 Composite ACT Score'])
# Out:
# [Text(0, 0, '2017 Composite ACT Score'),
#  Text(0, 0, '2018 Composite ACT Score')]

# %%
plt.figure(figsize = (8, 6))
plt.title('2017 and 2018 SAT Scores', fontsize = 20)
sns.boxplot(data = (final['sat_math'], final['sat_math_2018'], 
                    final['sat_eb_reading_and_writing'], final['sat_eb_reading_and_writing_2018']), 
            orient = 'h').set_yticklabels(['2017 Math', '2018 Math',
                                           '2017 E-B R&W', '2018 E-B R&W']);

# %%
plt.figure(figsize = (8, 6))
plt.title('2017 and 2018 ACT Scores ', fontsize = 20)
sns.boxplot(data = (final['act_math'], final['act_math_2018'], 
                    final['act_science'], final['act_science_2018'],
                    final['act_reading'], final['act_reading_2018'], 
                    final['act_english'], final['act_english_2018']), 
            orient = 'h').set_yticklabels(['2017 Math', '2018 Math',
                                           '2017 Science', '2018 Science',
                                           '2017 Reading', '2018 Reading',
                                           '2017 English', '2018 English']);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# create a sats dataframe made up of states, their respective participation rates in 2017 and 2018,
# and their respective 2017 and 2018 total scores
sats = final[['state', 'sat_participation', 'sat_participation_2018', 'sat_total', 'sat_total_2018']]

# create an acts dataframe made up of states, their respective participation rates in 2017 and 2018,
# and their respective 2017 and 2018 composite scores
acts = final[['state', 'act_participation', 'act_participation_2018', 'act_composite', 'act_composite_2018']]

# %%
acts['part_change'] = acts['act_participation_2018'] - acts['act_participation']
sats['part_change'] = sats['sat_participation_2018'] - sats['sat_participation']
acts['score_change'] = acts['act_composite_2018'] - acts['act_composite']
sats['score_change'] = sats['sat_total_2018'] - sats['sat_total']
# Out:
# /Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sorted_sat_change = sats[['state', 'part_change']].sort_values(by = 'part_change')
sat_by_score_change = sats[['state', 'score_change']].sort_values(by = 'score_change')

biggest_part_drops = sorted_sat_change[sorted_sat_change['part_change'] < 0].head()
biggest_part_increase = sorted_sat_change[sorted_sat_change['part_change'] > 0].tail()

big_score_drop = sat_by_score_change[sat_by_score_change['score_change'] < 0].head()
big_score_increase = sat_by_score_change[sat_by_score_change['score_change'] > 0].tail()

# %%
sorted_act_change = acts[['state', 'part_change']].sort_values(by = 'part_change')
act_by_score_change = acts[['state', 'score_change']].sort_values(by = 'score_change')

biggest_part_drops_act = sorted_act_change[sorted_act_change['part_change'] < 0].head()
biggest_part_increase_act = sorted_act_change[sorted_act_change['part_change'] > 0].tail()

big_score_drop_act = act_by_score_change[act_by_score_change['score_change'] < 0].head()
big_score_increase_act = act_by_score_change[act_by_score_change['score_change'] > 0].tail()

# %%
plt.figure(figsize = (7, 5))
plt.title('Decrease in SAT Participation from 2017 to 2018', fontsize = 18)
plt.barh(biggest_part_drops['state'], biggest_part_drops['part_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Increase in SAT Participation from 2017 to 2018', fontsize = 18)
plt.barh(biggest_part_increase['state'], biggest_part_increase['part_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Decrease in ACT Participation from 2017 to 2018', fontsize = 18)
plt.barh(biggest_part_drops_act['state'], biggest_part_drops_act['part_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Increase in ACT Participation from 2017 to 2018', fontsize = 18)
plt.barh(biggest_part_increase_act['state'], biggest_part_increase_act['part_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Decrease in Average Total SAT Score from 2017 to 2018', fontsize = 18)
plt.barh(big_score_drop['state'], big_score_drop['score_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Increase in Total Average SAT Scores from 2017 to 2018', fontsize = 18)
plt.barh(big_score_increase['state'], big_score_increase['score_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Decrease in Average Composite ACT Score from 2017 to 2018', fontsize = 18)
plt.barh(big_score_drop_act['state'], big_score_drop_act['score_change']);

# %%
plt.figure(figsize = (7, 5))
plt.title('Increase in Average Composite ACT Score from 2017 to 2018', fontsize = 18)
plt.barh(big_score_increase_act['state'], big_score_increase_act['score_change']);

# %%
# subplot_barh(biggest_part_drops, [''])

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %%
stats.normaltest(final['act_composite'])
# Out:
# NormaltestResult(statistic=6.557389886662569, pvalue=0.03767739587231253)

# %%
final['sat_math'].mode()
# Out:
# 0    524
# dtype: int64

# %%
final['sat_math'].mean()
# Out:
# 556.8823529411765

# %%
final['sat_math'].median()
# Out:
# 548.0

# %%
final.describe()
# Out:
#        sat_participation  sat_eb_reading_and_writing    sat_math    sat_total  \
# count          51.000000                   51.000000   51.000000    51.000000
# mean           39.803922                  569.117647  556.882353  1126.098039
# std            35.276632                   45.666901   47.121395    92.494812
# min             2.000000                  482.000000  468.000000   950.000000
# 25%             4.000000                  533.500000  523.500000  1055.500000
# 50%            38.000000                  559.000000  548.000000  1107.000000
# 75%            66.000000                  613.000000  599.000000  1212.000000
# max           100.000000                  644.000000  651.000000  1295.000000
#
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean           65.254902    20.931373  21.182353    22.013725    21.450980
# ...

# %%
# we can see the median (red line) is less than the mean (black line)

final['sat_math'].hist()
plt.axvline(final['sat_math'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(final['sat_math'].median(), color='r', linestyle='solid', linewidth=1);

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
#
#  - Normal distributions have a median (50th percentile, middle value) that is equal to the mean (average), with the right and left side being roughly evenly distributed around the middle.
#  - We say a distribution is right-skewed (longer tail to the right) when the mean is greater than the median, and we say a distribution is left-skewed (longer tail to the left) when the median is greater than the mean.
#  - From the .describe() method called above along with our histograms and box plots we created, we can see that a majority of the data points are right-skewed, meaning their mean is greater than the median

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
#
#  - We do not observe these trends.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# -  This may be due to the fact that we have varying degrees of participation from each individual state for each given test. If we had equal levels of participation from each state on each test, we would be more likely to see a normal distribution. Due to the negative correlation between participation and average test scores, we do not see a normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
#  - Yes. Given what's observed above, we see a negative correlation between participation rates and average test scores. Based on this, we can make educated assumptions on average test scores given the participation rates. Higher participation rates should result in lower average test scores, while lower participation rates result in higher average test scores.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
#  - The two test scores are largely unrelated. It is more appropriate to compare the specific SAT and ACT math scores with their respective participation rates. A high SAT math score does not necessarily mean a high or low ACT math score inherently.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
# Colorado, Illinois, Florida

# https://magoosh.com/hs/act/2017/states-that-require-the-act-or-sat/
# https://blog.prepscholar.com/which-states-require-the-sat
# https://www.the74million.org/the-states-that-spend-the-most-and-least-on-education-and-how-their-students-perform-compared-to-their-neighbors/

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
# Based on our observations, we can conclude that participation levels and average total/composite scores are 
# negatively correlated. That is, as the participation levels on a given test increases, we can expect the average 
# total/composite test score will also decrease. Similarly, as participation levels decrease, the average 
# total/composite score will increase. 

# This can be primarily observed in the states of Colorado and Illinois, where the SAT participation rates 
# jumped from 11% in 2017 to 100% in 2018 for Colorado, and 9% in 2017 to 99% in 2018 for Illinois. Conversely, 
# the average total SAT scores dropped from 1201 to 1025 for Colorado, and 1115 in 2017 to 2019 in 2018 for Illinois. 
# Florida, on the other hand, saw their SAT participation drop from 83% in 2017 to 56% in 2018. As expected, 
# their average total SAT score rose from 1017 in 2017 to 1099 in 2018.

# Given our observations, our goal is to increase participation on the SAT. We are not concerned with the 
# overall average scores. Due to this, my recommendation is that we avoid states where the ACT is mandatory and 
# focus on states that do not have mandatory testing one way or another. It will be beneficial to focus on states 
# that are in close proximity to those that have successfully transitioned to the SAT - such as Colorado or 
# Illinois. Looking at the surrounding states, we should focus on states such as New Mexico, which had an 
# 11% participation in 2017 and a 16% participation in 2018, or Iowa, which had a 2% participation rate in 
# 2017 and a 3% participation rate in 2018.
